# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import math

# %% [markdown]
# <font size="5"> <b>Preprocessing</b> </font>
#
# <font size="4">Read the csv files and estimates the metrics</font>
#
# <font size="4">EventosManabi.csv is dataset where you can find the historical records from users</font>

# %%
# Here I load the first file 
eventos= pd.read_csv('C:/Users/User/Downloads/EventosManabi.csv')
eventos['FechaEventoConv']=pd.to_datetime( pd.Series(pd.to_datetime(eventos["FechaEvento"].head()).astype(str)+' '+
                          eventos["Hora"].head().astype(str)+':00') )
eventos= eventos.set_index('FechaEventoConv')

# %%
eventos.head(5)
# Out:
#                      ID FechaEvento  Hora  BaseCliente ProvinciaCliente  \
# FechaEventoConv
# 2016-04-16 17:00:00   1  2016-04-16    17        50913           MANABI
# 2016-07-16 14:00:00   2  2016-07-16    14        40574         LOS RIOS
# 2016-07-17 15:00:00   3  2016-07-17    15        11308        PICHINCHA
# 2016-04-16 17:00:00   4  2016-04-16    17        52995           MANABI
# 2016-07-15 05:00:00   5  2016-07-15     5        40018            AZUAY
#
#                     CantonCliente CiudadCliente ParroquiaCliente  \
# FechaEventoConv
# 2016-04-16 17:00:00    PORTOVIEJO    PORTOVIEJO       PORTOVIEJO
# 2016-07-16 14:00:00       QUEVEDO       QUEVEDO          QUEVEDO
# 2016-07-17 15:00:00         QUITO         QUITO         CONOCOTO
# 2016-04-16 17:00:00    PORTOVIEJO    PORTOVIEJO       PORTOVIEJO
# 2016-07-15 05:00:00        CUENCA        CUENCA           CUENCA
#
#                      LatitudCliente  LongitudCliente  BaseEvento  \
# FechaEventoConv
# ...

# %%
eventos.groupby([eventos.index.day,'Hora'])['CantidadClientes'].sum()
# Out:
# FechaEventoConv  Hora
# 15               0       72843
#                  1       51406
#                  2       44614
#                  3       43847
#                  4       44618
#                          ...
# 18               19      50552
#                  20      56986
#                  21      57219
#                  22      51553
#                  23      40165
# Name: CantidadClientes, Length: 96, dtype: int64

# %%
import datetime
eventos["FechaEvento"] =  pd.to_datetime(eventos["FechaEvento"])
#eventos["Hora"] = pd.to_timedelta(eventos["Hora"])

# %%
pd.to_datetime( pd.Series(pd.to_datetime(eventos["FechaEvento"].head()).astype(str)+' '+
                          eventos["Hora"].head().astype(str)+':00') )
# Out:
# 0   2016-04-16 17:00:00
# 1   2016-07-16 14:00:00
# 2   2016-07-17 15:00:00
# 3   2016-04-16 17:00:00
# 4   2016-07-15 05:00:00
# dtype: datetime64[ns]
